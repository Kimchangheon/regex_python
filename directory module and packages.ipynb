# %%
import sys
sys.executable
# Out:
# '/home/kch/anaconda3/bin/python'

# %%
sys.path
# Out:
# ['/home/kch/aiffel/F-13',
#  '/home/kch/anaconda3/lib/python38.zip',
#  '/home/kch/anaconda3/lib/python3.8',
#  '/home/kch/anaconda3/lib/python3.8/lib-dynload',
#  '',
#  '/home/kch/anaconda3/lib/python3.8/site-packages',
#  '/home/kch/anaconda3/lib/python3.8/site-packages/IPython/extensions',
#  '/home/kch/.ipython']

# %% [markdown]
# file:///home/kch/%EB%8B%A4%EC%9A%B4%EB%A1%9C%EB%93%9C/lms.aiffel.io_steps2_751.png![lms.aiffel.io_steps2_751.png](attachment:lms.aiffel.io_steps2_751.png)![image.png](attachment:image.png)
